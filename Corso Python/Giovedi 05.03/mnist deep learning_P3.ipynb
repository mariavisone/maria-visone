# %%
# import os
# os.environ["KERAS_BACKEND"] = "torch"
import numpy as np
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout
from keras.utils import to_categorical
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam

# %%
# Caricamento del dataset MNIST

(X_train, y_train), (X_test, y_test) = mnist.load_data()


# Visualizzazione di un esempio

plt.imshow(X_train[0], cmap='gray')

plt.title(f'Etichetta: {y_train[0]}')

plt.show()


# Normalizzazione dei dati, le reti neurali funzionano SOLO con dati normalizzati

X_train = X_train.astype('float32') / 255

X_test = X_test.astype('float32') / 255


# Reshape dei dati

X_train = X_train.reshape(-1, 28*28)

X_test = X_test.reshape(-1, 28*28)


# Conversione delle etichette in formato one-hotencoding

y_train = to_categorical(y_train, num_classes=10)

y_test = to_categorical(y_test, num_classes=10)

# %%
# Creazione del modello

model = Sequential()


# Aggiunta degli strati

model.add(Dense(units=128, activation='relu', input_shape=(784,)))

model.add(Dropout(0.3))

model.add(Dense(units=64, activation='relu'))

model.add(Dropout(0.3))

model.add(Dense(units=10, activation='softmax'))
# Out:
# c:\Users\mbagn\anaconda3\envs\pytorch\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_9"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_21 (Dense)                │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_22 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_23 (Dense)                │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 109,386 (427.29 KB)
#  Trainable params: 109,386 (427.29 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
opt = Adam(learning_rate=0.001)

# %%
model.compile(optimizer=opt,

              loss='categorical_crossentropy',

              metrics=['accuracy'])

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

# 1. Stop training if val_loss doesn't improve for 7 epochs
early_stop = EarlyStopping(
    monitor='val_loss', 
    patience=7, 
    restore_best_weights=True,
    verbose=1
)

# 2. Halve the Learning Rate if val_loss doesn't improve for 3 epochs
reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.5,      # Factor by which the learning rate will be reduced (0.5 = half)
    patience=3,      # Number of epochs with no improvement after which learning rate will be reduced
    min_lr=1e-6,     # Lower bound on the learning rate
    verbose=1
)

# %%
history = model.fit(X_train, y_train,

                    epochs=100,

                    batch_size=64,

                    validation_split=0.1,

                    callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8574 - loss: 0.4669 - val_accuracy: 0.9610 - val_loss: 0.1325 - learning_rate: 0.0010
# Epoch 2/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9347 - loss: 0.2240 - val_accuracy: 0.9708 - val_loss: 0.0987 - learning_rate: 0.0010
# Epoch 3/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9478 - loss: 0.1766 - val_accuracy: 0.9735 - val_loss: 0.0911 - learning_rate: 0.0010
# Epoch 4/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9555 - loss: 0.1505 - val_accuracy: 0.9755 - val_loss: 0.0825 - learning_rate: 0.0010
# Epoch 5/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9594 - loss: 0.1335 - val_accuracy: 0.9760 - val_loss: 0.0829 - learning_rate: 0.0010
# Epoch 6/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9632 - loss: 0.1211 - val_accuracy: 0.9755 - val_loss: 0.0835 - learning_rate: 0.0010
# Epoch 7/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9656 - loss: 0.1145 - val_accuracy: 0.9793 - val_loss: 0.0718 - learning_rate: 0.0010
# Epoch 8/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9682 - loss: 0.1041 - val_accuracy: 0.9767 - val_loss: 0.0737 - learning_rate: 0.0010
# Epoch 9/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9691 - loss: 0.1018 - val_accuracy: 0.9780 - val_loss: 0.0696 - learning_rate: 0.0010
# Epoch 10/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9711 - loss: 0.0927 - val_accuracy: 0.9788 - val_loss: 0.0681 - learning_rate: 0.0010
# Epoch 11/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9726 - loss: 0.0888 - val_accuracy: 0.9798 - val_loss: 0.0672 - learning_rate: 0.0010
# Epoch 12/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9744 - loss: 0.0823 - val_accuracy: 0.9810 - val_loss: 0.0670 - learning_rate: 0.0010
# Epoch 13/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9746 - loss: 0.0811 - val_accuracy: 0.9795 - val_loss: 0.0773 - learning_rate: 0.0010
# Epoch 14/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9758 - loss: 0.0747 - val_accuracy: 0.9817 - val_loss: 0.0671 - learning_rate: 0.0010
# Epoch 15/100
# 833/844 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9788 - loss: 0.0698
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9770 - loss: 0.0749 - val_accuracy: 0.9808 - val_loss: 0.0730 - learning_rate: 0.0010
# Epoch 16/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9809 - loss: 0.0607 - val_accuracy: 0.9827 - val_loss: 0.0613 - learning_rate: 5.0000e-04
# Epoch 17/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9828 - loss: 0.0533 - val_accuracy: 0.9825 - val_loss: 0.0655 - learning_rate: 5.0000e-04
# Epoch 18/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9823 - loss: 0.0570 - val_accuracy: 0.9830 - val_loss: 0.0647 - learning_rate: 5.0000e-04
# Epoch 19/100
# 826/844 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9851 - loss: 0.0483
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9838 - loss: 0.0512 - val_accuracy: 0.9827 - val_loss: 0.0637 - learning_rate: 5.0000e-04
# Epoch 20/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9852 - loss: 0.0461 - val_accuracy: 0.9837 - val_loss: 0.0647 - learning_rate: 2.5000e-04
# Epoch 21/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9861 - loss: 0.0457 - val_accuracy: 0.9842 - val_loss: 0.0595 - learning_rate: 2.5000e-04
# Epoch 22/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9864 - loss: 0.0439 - val_accuracy: 0.9827 - val_loss: 0.0616 - learning_rate: 2.5000e-04
# Epoch 23/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9859 - loss: 0.0439 - val_accuracy: 0.9843 - val_loss: 0.0626 - learning_rate: 2.5000e-04
# Epoch 24/100
# 824/844 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9860 - loss: 0.0430
# Epoch 24: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9859 - loss: 0.0432 - val_accuracy: 0.9843 - val_loss: 0.0626 - learning_rate: 2.5000e-04
# Epoch 25/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9871 - loss: 0.0395 - val_accuracy: 0.9838 - val_loss: 0.0627 - learning_rate: 1.2500e-04
# Epoch 26/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9878 - loss: 0.0362 - val_accuracy: 0.9838 - val_loss: 0.0624 - learning_rate: 1.2500e-04
# Epoch 27/100
# 829/844 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9869 - loss: 0.0397
# Epoch 27: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9874 - loss: 0.0393 - val_accuracy: 0.9837 - val_loss: 0.0633 - learning_rate: 1.2500e-04
# Epoch 28/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9883 - loss: 0.0360 - val_accuracy: 0.9838 - val_loss: 0.0633 - learning_rate: 6.2500e-05
# Epoch 28: early stopping
# Restoring model weights from the end of the best epoch: 21.

# %%
import matplotlib.pyplot as plt

# Creiamo una figura con due grafici (Sottoplot)
plt.figure(figsize=(12, 5))

# Grafico della Precisione (Accuracy)
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuratezza del Modello')
plt.xlabel('Epoca')
plt.ylabel('Accuracy')
plt.legend()

# Grafico della Perdita (Loss)
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Perdita del Modello')
plt.xlabel('Epoca')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)

print(f'Perdita sul test set: {test_loss:.4f}')

print(f'Accuratezza sul test set: {test_accuracy:.4f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9815 - loss: 0.0721
# Perdita sul test set: 0.0721
# Accuratezza sul test set: 0.9815

# %% [markdown]
# # Convoluzionali

# %%
import os
os.environ["KERAS_BACKEND"] = "torch"
import numpy as np
from keras.datasets import fashion_mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten, Dropout, Conv2D, MaxPooling2D, Input
from keras.utils import to_categorical
import matplotlib.pyplot as plt
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from keras.optimizers import Adam

# %%
# 1. Caricamento del dataset Fashion MNIST
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()

# Visualizzazione di un esempio (Capi di abbigliamento invece di cifre)
plt.imshow(X_train[0], cmap='gray')
plt.title(f'Etichetta: {y_train[0]}')
plt.show()

# 2. Normalizzazione
X_train = X_train.astype('float32') / 255
X_test = X_test.astype('float32') / 255

# 3. Reshape per CNN (Samples, Height, Width, Channels)
# Per le CNN serve la dimensione del canale (1 per scala di grigi)
X_train = X_train.reshape(-1, 28, 28, 1)
X_test = X_test.reshape(-1, 28, 28, 1)

# Conversione delle etichette in formato one-hot encoding
y_train = to_categorical(y_train, num_classes=10)
y_test = to_categorical(y_test, num_classes=10)

# %%
# 4. Creazione del modello Convoluzionale
model = Sequential()

# Input layer (scelta consigliata da Keras 3 invece di input_shape nei layer)
model.add(Input(shape=(28, 28, 1)))

# Primo blocco convoluzionale: estrazione caratteristiche spaziali
model.add(Conv2D(filters=32, kernel_size=(3, 3), activation='relu')) # quello che crea la matrice di trasformazione
model.add(MaxPooling2D(pool_size=(2, 2)))

# Secondo blocco convoluzionale
model.add(Conv2D(filters=64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

# Appiattimento e strati densi (simili al tuo codice originale)
model.add(Flatten())
model.add(Dense(units=128, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=64, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(units=10, activation='softmax'))

# %%
# 5. Sommario e Compilazione
model.summary()
# Out:
# Model: "sequential_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_2 (Conv2D)               │ (None, 26, 26, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 13, 13, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 11, 11, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 5, 5, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 1600)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_24 (Dense)                │ (None, 128)            │       204,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_25 (Dense)                │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_26 (Dense)                │ (None, 10)             │           650 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 232,650 (908.79 KB)
#  Trainable params: 232,650 (908.79 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
opt = Adam(learning_rate=0.001)
model.compile(optimizer=opt,
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
# 6. Callbacks (identici all'originale)
early_stop = EarlyStopping(
    monitor='val_loss', 
    patience=7, 
    restore_best_weights=True,
    verbose=1
)

reduce_lr = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.5,
    patience=3,
    min_lr=1e-6,
    verbose=1
)

# %%
# 7. Addestramento
history = model.fit(X_train, y_train,
                    epochs=100,
                    batch_size=64,
                    validation_split=0.1,
                    callbacks=[early_stop, reduce_lr])
# Out:
# Epoch 1/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.7702 - loss: 0.6386 - val_accuracy: 0.8657 - val_loss: 0.3695 - learning_rate: 0.0010
# Epoch 2/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.8602 - loss: 0.3956 - val_accuracy: 0.8790 - val_loss: 0.3164 - learning_rate: 0.0010
# Epoch 3/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.8815 - loss: 0.3327 - val_accuracy: 0.8877 - val_loss: 0.2929 - learning_rate: 0.0010
# Epoch 4/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.8914 - loss: 0.3001 - val_accuracy: 0.8958 - val_loss: 0.2822 - learning_rate: 0.0010
# Epoch 5/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 10ms/step - accuracy: 0.9038 - loss: 0.2716 - val_accuracy: 0.9047 - val_loss: 0.2574 - learning_rate: 0.0010
# Epoch 6/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9075 - loss: 0.2542 - val_accuracy: 0.9087 - val_loss: 0.2475 - learning_rate: 0.0010
# Epoch 7/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9135 - loss: 0.2382 - val_accuracy: 0.9122 - val_loss: 0.2378 - learning_rate: 0.0010
# Epoch 8/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9181 - loss: 0.2233 - val_accuracy: 0.9132 - val_loss: 0.2353 - learning_rate: 0.0010
# Epoch 9/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9239 - loss: 0.2093 - val_accuracy: 0.9112 - val_loss: 0.2358 - learning_rate: 0.0010
# Epoch 10/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9280 - loss: 0.1960 - val_accuracy: 0.9118 - val_loss: 0.2475 - learning_rate: 0.0010
# Epoch 11/100
# 841/844 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9314 - loss: 0.1854
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9315 - loss: 0.1859 - val_accuracy: 0.9150 - val_loss: 0.2363 - learning_rate: 0.0010
# Epoch 12/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9440 - loss: 0.1538 - val_accuracy: 0.9197 - val_loss: 0.2316 - learning_rate: 5.0000e-04
# Epoch 13/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9467 - loss: 0.1430 - val_accuracy: 0.9185 - val_loss: 0.2420 - learning_rate: 5.0000e-04
# Epoch 14/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9506 - loss: 0.1353 - val_accuracy: 0.9197 - val_loss: 0.2398 - learning_rate: 5.0000e-04
# Epoch 15/100
# 842/844 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9544 - loss: 0.1255
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9517 - loss: 0.1303 - val_accuracy: 0.9178 - val_loss: 0.2398 - learning_rate: 5.0000e-04
# Epoch 16/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9590 - loss: 0.1113 - val_accuracy: 0.9227 - val_loss: 0.2449 - learning_rate: 2.5000e-04
# Epoch 17/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9606 - loss: 0.1074 - val_accuracy: 0.9202 - val_loss: 0.2612 - learning_rate: 2.5000e-04
# Epoch 18/100
# 840/844 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9645 - loss: 0.0970
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.9639 - loss: 0.0987 - val_accuracy: 0.9217 - val_loss: 0.2539 - learning_rate: 2.5000e-04
# Epoch 19/100
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9671 - loss: 0.0906 - val_accuracy: 0.9240 - val_loss: 0.2560 - learning_rate: 1.2500e-04
# Epoch 19: early stopping
# Restoring model weights from the end of the best epoch: 12.

# %%
# 8. Visualizzazione Risultati
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Accuratezza Fashion MNIST')
plt.xlabel('Epoca')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Perdita Fashion MNIST')
plt.xlabel('Epoca')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
# 9. Valutazione finale
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print(f'Perdita sul test set: {test_loss:.4f}')
print(f'Accuratezza sul test set: {test_accuracy:.4f}')
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9145 - loss: 0.2479
# Perdita sul test set: 0.2479
# Accuratezza sul test set: 0.9145

# %%
import datetime
from keras.callbacks import TensorBoard

# 1. Setup the log directory
log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")

# 2. Define the callback
# histogram_freq=1 allows you to see the weights changing in each layer
tensorboard_callback = TensorBoard(log_dir=log_dir, histogram_freq=1)

# 3. Add it to your model.fit (using the Fashion MNIST CNN from before)
history = model.fit(
    X_train, y_train,
    epochs=10, 
    batch_size=64,
    validation_split=0.1,
    callbacks=[early_stop, reduce_lr, tensorboard_callback] # <--- Added here
)
# Out:
# Epoch 1/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9510 - loss: 0.1325 - val_accuracy: 0.9215 - val_loss: 0.2320 - learning_rate: 1.2500e-04
# Epoch 2/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9540 - loss: 0.1252 - val_accuracy: 0.9215 - val_loss: 0.2324 - learning_rate: 1.2500e-04
# Epoch 3/10
# 843/844 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9563 - loss: 0.1211
# Epoch 3: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9564 - loss: 0.1202 - val_accuracy: 0.9208 - val_loss: 0.2412 - learning_rate: 1.2500e-04
# Epoch 4/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9581 - loss: 0.1134 - val_accuracy: 0.9218 - val_loss: 0.2407 - learning_rate: 6.2500e-05
# Epoch 5/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9584 - loss: 0.1126 - val_accuracy: 0.9218 - val_loss: 0.2418 - learning_rate: 6.2500e-05
# Epoch 6/10
# 843/844 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9595 - loss: 0.1093
# Epoch 6: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9596 - loss: 0.1106 - val_accuracy: 0.9223 - val_loss: 0.2422 - learning_rate: 6.2500e-05
# Epoch 7/10
# 844/844 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9604 - loss: 0.1069 - val_accuracy: 0.9233 - val_loss: 0.2427 - learning_rate: 3.1250e-05
# Epoch 7: early stopping
# Restoring model weights from the end of the best epoch: 1.

# %%
# !tensorboard --logdir logs # si apre su http://localhost:6006
# Out:
# ^C

# %%
import keras
from keras.models import Model
import matplotlib.pyplot as plt
import numpy as np

def plot_first_layer_feature_maps(trained_model, input_image):
    # 1. Find the first Conv2D layer
    first_conv_layer = None
    for layer in trained_model.layers:
        if 'conv2d' in layer.name:
            first_conv_layer = layer
            break
            
    if first_conv_layer is None:
        print("Error: No Conv2D layer found.")
        return

    # 2. Build a functional model explicitly for visualization
    # This avoids the "layer not called" error by creating a new path
    img_input = keras.Input(shape=(28, 28, 1))
    x = first_conv_layer(img_input)
    activation_model = Model(inputs=img_input, outputs=x)
    
    # 3. Prepare the single image
    # Ensure image is (28, 28, 1) and add batch dim -> (1, 28, 28, 1)
    img_tensor = np.expand_dims(input_image, axis=0)
    
    # 4. Generate the 32 "modified versions"
    feature_maps = activation_model.predict(img_tensor, verbose=0)
    
    # 5. Plotting
    plt.figure(figsize=(20, 10))
    for i in range(32):
        plt.subplot(4, 8, i + 1)
        # We take the i-th filter from the first image in batch
        plt.imshow(feature_maps[0, :, :, i], cmap='viridis')
        plt.axis('off')
        plt.title(f"Filter {i+1}", fontsize=10)
    
    plt.suptitle(f"The 32 'modified versions' of the image (Layer: {first_conv_layer.name})", fontsize=20)
    plt.tight_layout()
    plt.subplots_adjust(top=0.9)
    plt.show()

# Run it
plot_first_layer_feature_maps(model, X_test[0])
